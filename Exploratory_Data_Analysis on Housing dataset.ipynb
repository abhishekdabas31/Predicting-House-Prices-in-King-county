# %% [markdown]
# ## Loading the Data
# leading the data from `.csv` using pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("kc_house_data/kc_house_data.csv")

# %%
# diaplay the top5 rows using .head()
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# Looks good!!

# %% [markdown]
# ## Now its time for some general data inspection.
# Let's first examine to see if there are any `nulls` in the dataframe as well as look at the `type` of the data (i.e whether it is a string or numeric)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data.shape
# Out:
# (21613, 21)

# %%
# displaying the corrlation in rows
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
data.isnull().any()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %% [markdown]
# No `Null values` in our data!!!
# so the we are good to proceed!!
# Always good to check the percentage of null values, to calculate if we need to remove or change the values!!

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                Total  Percent
# sqft_lot15         0      0.0
# view               0      0.0
# date               0      0.0
# price              0      0.0
# bedrooms           0      0.0
# bathrooms          0      0.0
# sqft_living        0      0.0
# sqft_lot           0      0.0
# floors             0      0.0
# waterfront         0      0.0
# condition          0      0.0
# sqft_living15      0      0.0
# grade              0      0.0
# sqft_above         0      0.0
# sqft_basement      0      0.0
# yr_built           0      0.0
# yr_renovated       0      0.0
# zipcode            0      0.0
# lat                0      0.0
# long               0      0.0

# %% [markdown]
# ## Hence this dataset is clean of missing data.

# %%
data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# using `.value_counts()` to analyse the top and most recurring price for House

# %%
data.price.value_counts(ascending= False)
# Out:
# 450000.0    172
# 350000.0    172
# 550000.0    159
# 500000.0    152
# 425000.0    150
#            ...
# 641500.0      1
# 575950.0      1
# 674250.0      1
# 608700.0      1
# 884744.0      1
# Name: price, Length: 4028, dtype: int64

# %% [markdown]
# ## Checking the duplicated rows (if present)
# using `data.duplicated()`

# %%
duplicate_rows= data[data.duplicated()]

# %%
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# so, there are no duplicated rows!!
# The data looks in a good form then.

# %% [markdown]
# ## The data looks pretty clean!!!
# There are no nulls which we need to treat and most of the features are in numeric format(others in Float).

# %% [markdown]
# We would not need "id" and "date" for the analysis, so we can drop these columns

# %%
temp_data = data.drop(['id', 'date'],axis=1)

# %%
temp_data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
data['price'].mean()
# Out:
# 540088.1417665294

# %% [markdown]
# ## Adding "High" and "Low" Columns to table according to their price average as calculated

# %%
data['High/Low'] = ['High'if x>=540088 else 'Low' for x in data['price']]

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# Lets look at all the columns, using `pd.set_option('display.max_columns', None)`

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.shape
# Out:
# (21613, 22)

# %% [markdown]
# ## Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Lets check the opions for the number of bedrooms that are there in the data

# %%
data.bedrooms.unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
data.groupby('bedrooms')[['price', 'bedrooms', 'bathrooms']].median()
# Out:
#              price  bedrooms  bathrooms
# bedrooms
# 0         288000.0         0       0.00
# 1         299000.0         1       1.00
# 2         374000.0         2       1.00
# 3         413000.0         3       2.00
# 4         549997.5         4       2.50
# 5         620000.0         5       2.75
# 6         650000.0         6       3.00
# 7         728580.0         7       3.50
# 8         700000.0         8       3.25
# 9         817000.0         9       4.25
# 10        660000.0        10       3.00
# 11        520000.0        11       3.00
# 33        640000.0        33       1.75

# %% [markdown]
# ## Pairplot Visualisation
#
# Let's create some Seaborn pairplots for the features ('sqft_lot','sqft_above','price','sqft_living','bedrooms') to get a overview for how the various features are distributed vis-a-vis the price as well as the number of bedrooms

# %%
with sns.plotting_context("notebook",font_scale=2.5):
    g = sns.pairplot(data[['sqft_lot','sqft_above','price','sqft_living','bedrooms']], 
                 hue='bedrooms', palette='tab20',size=6)
g.set(xticklabels=[]);

# %%
#scatterplot
sns.set()
cols = ['price', 'sqft_living', 'grade', 'sqft_above', 'view', 'bathrooms']
sns.pairplot(data[cols], size = 2.5)
plt.show();

# %%
data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002925D61C148>,
# ...
#       dtype=object)

# %%
sns.distplot(data['price'], bins=50, kde=True);

# %%
sns.distplot(data['floors'] );

# %% [markdown]
# 1.Skewness refers to the degree of symmetry,
# 2.kurtosis refers to the degree of presence of outliers in the distribution.

# %%
print("Skewness: %f" % data['price'].skew())
print("Kurtosis: %f" % data['price'].kurt())
# Out:
# Skewness: 4.024069
# Kurtosis: 34.585540

# %%
sns.boxplot(x=data['price'])

# %% [markdown]
# # Visualizing linear relationships

# %%
sns.regplot(data['bedrooms'],data['price'])

# %%
sns.regplot(data['bathrooms'],data['price'])

# %%
sns.regplot(data['sqft_living'],data['price'])

# %%
sns.regplot(data['sqft_living'],data['sqft_above'])

# %%
sns.regplot(data['bathrooms'],data['grade'])

# %%
sns.lmplot(x="sqft_living", y="price", data=data)

# %%
#data["big_tip"] = (data.bedrooms / data.price) > .15
sns.lmplot(x="price", y="bedrooms", data=data,
           y_jitter=.03)

# %%
sns.lmplot(x="bedrooms", y="price",  data=data)

# %% [markdown]
# # Correlation graphs

# %%
corrmat = data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'price')['price'].index
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Highest correlation tp price can be found with columns like:-
# sqft_living,
# grade,
# sqft_above,
# sqft_living15

# %% [markdown]
# These overall scatterplots above, confirm the findings of the heatmap. There is myriad of linear correlation between sqft_living, sqft_above, bathrooms and grade. This yields an opportunity for to combine features.
# Moreover, we found that the above mentioned features have the biggest impact on sale price. One would also expect location to play a role, but as they are in latitude/longitude coordinates, it requires advanced data manipulation to take it into account. Finally, due to many linear relationships we can apply regression models.

# %%
corr = data.drop('price', axis=1).corr() # We already examined SalePrice correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'High'],
#       dtype='object')

# %%
#Scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(data['price'], data['bedrooms'])
ax.set_xlabel('price')
ax.set_ylabel('bedrooms')
plt.show()

# %%
var = 'sqft_living15'
data_temp = pd.concat([data['price'], data[var]], axis=1)
data_temp.plot.scatter(x=var, y='price', ylim=(3,8000000));
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Box-Plot
# A Box-Plot is a visual representation of a five point summary, with some additional information about outliers (1.5 times the lower and upper quartiles)

# %%
sns.stripplot(x="bedrooms", y="price", data=data)

# %%
sns.boxplot(x="floors", y="price",  data=data)

# %%
var = 'grade'
data_temp = pd.concat([data['price'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="price", data=data_temp)
fig.axis(ymin=0, ymax=3500000);

# %%
var = 'grade'
data_temp = pd.concat([data['price'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 6))
fig = sns.boxplot(x=var, y="price", data=data_temp)
fig.axis(ymin=0, ymax=3500000);

# %%
var = 'bathrooms'
data_temp = pd.concat([data['price'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 20))
fig = sns.boxplot(x=var, y="price", data=data_temp)
fig.axis(ymin=0, ymax=3500000);


# var = 'bathrooms'
# data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
# f, ax = plt.subplots(figsize=(20, 20))
# fig = sns.boxplot(x=var, y="SalePrice", data=data)
# fig.axis(ymin=0, ymax=3500000);

# %% [markdown]
# # Violin plots
# A violin plot is a method of plotting numeric data. It is a box plot with a rotated kernel density plot on each side. The violin plot is similar to box plots, except that they also show the probability density of the data at different values.

# %%
sns.violinplot(x="floors", y="price" , data=data)

# %%
import numpy as np

# %%
np.random.seed(sum(map(ord, "distributions")))

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
no_nan= data['price'][~np.isnan(data['price'])]

# %%
no_nan
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
#checking distribution of GDP of the world
sns.distplot(np.array(no_nan))

# %%
no_nan_2= data['sqft_lot'][~np.isnan(data['sqft_lot'])]

# %%
no_nan_2
# Out:
# 0         5650
# 1         7242
# 2        10000
# 3         5000
# 4         8080
#          ...
# 21608     1131
# 21609     5813
# 21610     1350
# 21611     2388
# 21612     1076
# Name: sqft_lot, Length: 21613, dtype: int64

# %%
sns.distplot(np.array(no_nan_2))

# %%
import plotly.express as px

# %%
pc3 = result[:,2]

# %%
pcs = pd.DataFrame(list(zip(pc1, pc2, pc3, species)),columns =['pc1', 'pc2', 'pc3', 'species']) 
fig = px.scatter_3d(pcs, x='pc1', y='pc2', z='pc3',color='species')
fig.show()

# %% [markdown]
# ## Checking if data is in Normal form

# %%
# Checking for Price column

sns.distplot(data["price"])
fig = plt.figure()
res = stats.probplot(data['price'], plot=plt)

# %%
# Checking for sqft_living column

sns.distplot(data["sqft_living"])
fig = plt.figure()
res = stats.probplot(data['sqft_living'], plot=plt)

# %%
# Checking for grade column
sns.distplot(data["grade"])

# %% [markdown]
# ## It is not in normal form

# %%
data["grade"]=np.log(data["grade"])

# %%
from scipy.stats import norm
from scipy import stats
sns.distplot(data['grade'], fit=norm,  bins=50, kde=False);
fig = plt.figure()
res = stats.probplot(data['grade'], plot=plt)

# %%
# Checking for sqft_living15 column
sns.distplot(data["sqft_living15"])

# %% [markdown]
# Not in normal form

# %%
data["sqft_living15"]=np.log(data["sqft_living15"])

# %%
sns.distplot(data['sqft_living15'], fit=norm,  bins=50, kde=False);
fig = plt.figure()
res = stats.probplot(data['sqft_living15'], plot=plt)

# %% [markdown]
# ## Now there is a nice linear relationship between the features

# %% [markdown]
# # Fitting the Machine Learning models to our data

# %%
from sklearn import ensemble, tree, linear_model
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error

# %%
x_columns = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
       'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
       'sqft_living15', 'sqft_lot15']
x=data[x_columns]

y_columns= ["price"]
y=data[y_columns]

# %%
train_x, test_x,train_y,test_y = train_test_split(x,y,)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(train_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
accuracy = regressor.score(test_x, test_y)
"Accuracy: {}%".format(int(round(accuracy * 100)))
# Out:
# 'Accuracy: 68%'

# %%
pred_y= regressor.predict(test_x)

# %%
pred_y=pd.DataFrame(pred_y)

# %%
table_compare= pd.concat([test_y,pred_y])    #pd.DataFrame({'Actual':test_y , 'Predicted':pred_y})
table_compare
# Out:
#            price              0
# 13327   452500.0            NaN
# 1124    505000.0            NaN
# 1818   1430000.0            NaN
# 3127    176500.0            NaN
# 18913   224000.0            NaN
# ...          ...            ...
# 5399         NaN  207021.754721
# 5400         NaN  596094.116714
# 5401         NaN  738816.271460
# 5402         NaN  232756.134424
# 5403         NaN  427353.023522
#
# [10808 rows x 2 columns]

# %% [markdown]
# Lets try other algorithms
